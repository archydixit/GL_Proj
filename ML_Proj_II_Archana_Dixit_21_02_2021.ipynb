# %% [markdown]
# ## Problem 2
# ### In this particular project, we are going to work on the inaugural corpora from the nltk in Python. We will be looking at the following speeches of the Presidents of the United States of America:
#
# * President Franklin D. Roosevelt in 1941
# * President John F. Kennedy in 1961
# * President Richard Nixon in 1973
# * Find the number of characters, words and sentences for the mentioned documents. – 3 Marks

# %%
import numpy as np
import pandas as pd
import nltk
import random
from nltk.stem.snowball import SnowballStemmer
import json
import re
import string
from collections import Counter
cnt = Counter()

# %%
import warnings
warnings.filterwarnings("ignore")

# %%
stopwords = nltk.corpus.stopwords.words('english') +list(string.punctuation)
stopwords.append("--")

# %%
stemmer = SnowballStemmer("english")

# %%
nltk.download('inaugural')
# Out:
# [nltk_data] Downloading package inaugural to
# [nltk_data]     C:\Users\archy\AppData\Roaming\nltk_data...
# [nltk_data]   Package inaugural is already up-to-date!
# True

# %%
from nltk.corpus import inaugural

# %%
inaugural.fileids()
# Out:
# ['1789-Washington.txt',
#  '1793-Washington.txt',
#  '1797-Adams.txt',
#  '1801-Jefferson.txt',
#  '1805-Jefferson.txt',
#  '1809-Madison.txt',
#  '1813-Madison.txt',
#  '1817-Monroe.txt',
#  '1821-Monroe.txt',
#  '1825-Adams.txt',
#  '1829-Jackson.txt',
#  '1833-Jackson.txt',
#  '1837-VanBuren.txt',
#  '1841-Harrison.txt',
#  '1845-Polk.txt',
#  '1849-Taylor.txt',
#  '1853-Pierce.txt',
#  '1857-Buchanan.txt',
#  '1861-Lincoln.txt',
#  '1865-Lincoln.txt',
#  '1869-Grant.txt',
#  '1873-Grant.txt',
#  '1877-Hayes.txt',
#  '1881-Garfield.txt',
#  '1885-Cleveland.txt',
#  '1889-Harrison.txt',
#  '1893-Cleveland.txt',
#  '1897-McKinley.txt',
#  '1901-McKinley.txt',
#  '1905-Roosevelt.txt',
#  '1909-Taft.txt',
#  '1913-Wilson.txt',
#  '1917-Wilson.txt',
#  '1921-Harding.txt',
#  '1925-Coolidge.txt',
#  '1929-Hoover.txt',
#  '1933-Roosevelt.txt',
#  '1937-Roosevelt.txt',
#  '1941-Roosevelt.txt',
#  '1945-Roosevelt.txt',
#  '1949-Truman.txt',
#  '1953-Eisenhower.txt',
# ...

# %%
df=inaugural.raw('1941-Roosevelt.txt')
df1=inaugural.raw('1961-Kennedy.txt')
df2=inaugural.raw('1973-Nixon.txt')

# %% [markdown]
# ### Find the number of characters, words and sentences for the mentioned documents. – 3 Marks

# %%
number_of_characters = len(df)
number_of_characters
# Out:
# 7571

# %%
number_of_characters = len(df1)
number_of_characters
# Out:
# 7618

# %%
number_of_characters = len(df2)
number_of_characters
# Out:
# 9991

# %%
len(inaugural.words('1941-Roosevelt.txt'))
# Out:
# 1536

# %%
len(inaugural.words('1961-Kennedy.txt'))
# Out:
# 1546

# %%
len(inaugural.words('1973-Nixon.txt'))
# Out:
# 2028

# %%
#len(inaugural.sent('1973-Nixon.txt'))
import nltk
nltk.download('punkt')
from nltk.tokenize import sent_tokenize
number_of_sentences1 = sent_tokenize(df)

print(len(number_of_sentences1))
# Out:
# 68
# [nltk_data] Downloading package punkt to
# [nltk_data]     C:\Users\archy\AppData\Roaming\nltk_data...
# [nltk_data]   Package punkt is already up-to-date!

# %%
number_of_sentences2 = sent_tokenize(df1)

print(len(number_of_sentences2))
# Out:
# 52

# %%
number_of_sentences3 = sent_tokenize(df2)

print(len(number_of_sentences3))
# Out:
# 68

# %% [markdown]
# ###  Remove all the stopwords from the three speeches.

# %%
stopwords = nltk.corpus.stopwords.words('english') +list(string.punctuation)

all_words1 = (w.lower() for w in inaugural.words('1941-Roosevelt.txt'))
all_words_clean1 = [word for word in all_words1 if word not in stopwords]
all_words_freq1 = nltk.FreqDist(all_words_clean1)
word_features1 = [item[0] for item in all_words_freq1.most_common(2000)]

# %%
#After the stopwords 
all_words_clean1
# Out:
# ['national',
#  'day',
#  'inauguration',
#  'since',
#  '1789',
#  'people',
#  'renewed',
#  'sense',
#  'dedication',
#  'united',
#  'states',
#  'washington',
#  'day',
#  'task',
#  'people',
#  'create',
#  'weld',
#  'together',
#  'nation',
#  'lincoln',
#  'day',
#  'task',
#  'people',
#  'preserve',
#  'nation',
#  'disruption',
#  'within',
#  'day',
#  'task',
#  'people',
#  'save',
#  'nation',
#  'institutions',
#  'disruption',
#  'without',
#  'us',
#  'come',
#  'time',
#  'midst',
#  'swift',
#  'happenings',
#  'pause',
#  'moment',
#  'take',
#  'stock',
#  '--',
#  'recall',
#  'place',
#  'history',
#  'rediscover',
#  'may',
#  'risk',
#  'real',
#  'peril',
#  'inaction',
#  'lives',
#  'nations',
#  'determined',
#  'count',
#  'years',
#  'lifetime',
#  'human',
#  'spirit',
#  'life',
#  'man',
#  'three',
#  'score',
#  'years',
#  'ten',
#  'little',
#  'little',
#  'less',
#  'life',
#  'nation',
#  'fullness',
#  'measure',
#  'live',
#  'men',
# ...

# %%
#stopwords = nltk.corpus.stopwords.words('english') +list(string.punctuation)
all_words2 = (w.lower() for w in inaugural.words('1961-Kennedy.txt'))
all_words_clean2 = [word for word in all_words2 if word not in stopwords]
all_words_freq2 = nltk.FreqDist(all_words_clean2)

word_features2 = [item[0] for item in all_words_freq2.most_common(2000)]
word_features2[1:4]
# Out:
# ['let', 'us', 'world']

# %%
all_words_clean2
# Out:
# ['vice',
#  'president',
#  'johnson',
#  'mr',
#  'speaker',
#  'mr',
#  'chief',
#  'justice',
#  'president',
#  'eisenhower',
#  'vice',
#  'president',
#  'nixon',
#  'president',
#  'truman',
#  'reverend',
#  'clergy',
#  'fellow',
#  'citizens',
#  'observe',
#  'today',
#  'victory',
#  'party',
#  'celebration',
#  'freedom',
#  '--',
#  'symbolizing',
#  'end',
#  'well',
#  'beginning',
#  '--',
#  'signifying',
#  'renewal',
#  'well',
#  'change',
#  'sworn',
#  'almighty',
#  'god',
#  'solemn',
#  'oath',
#  'forebears',
#  'l',
#  'prescribed',
#  'nearly',
#  'century',
#  'three',
#  'quarters',
#  'ago',
#  'world',
#  'different',
#  'man',
#  'holds',
#  'mortal',
#  'hands',
#  'power',
#  'abolish',
#  'forms',
#  'human',
#  'poverty',
#  'forms',
#  'human',
#  'life',
#  'yet',
#  'revolutionary',
#  'beliefs',
#  'forebears',
#  'fought',
#  'still',
#  'issue',
#  'around',
#  'globe',
#  '--',
#  'belief',
#  'rights',
#  'man',
#  'come',
# ...

# %%
all_words3 = (w.lower() for w in inaugural.words('1973-Nixon.txt'))
all_words_clean3 = [word for word in all_words3 if word not in stopwords]
all_words_freq3 = nltk.FreqDist(all_words_clean3)

word_features3 = [item[0] for item in all_words_freq3.most_common(2000)]

# %%
all_words_clean3
# Out:
# ['mr',
#  'vice',
#  'president',
#  'mr',
#  'speaker',
#  'mr',
#  'chief',
#  'justice',
#  'senator',
#  'cook',
#  'mrs',
#  'eisenhower',
#  'fellow',
#  'citizens',
#  'great',
#  'good',
#  'country',
#  'share',
#  'together',
#  'met',
#  'four',
#  'years',
#  'ago',
#  'america',
#  'bleak',
#  'spirit',
#  'depressed',
#  'prospect',
#  'seemingly',
#  'endless',
#  'war',
#  'abroad',
#  'destructive',
#  'conflict',
#  'home',
#  'meet',
#  'today',
#  'stand',
#  'threshold',
#  'new',
#  'era',
#  'peace',
#  'world',
#  'central',
#  'question',
#  'us',
#  'shall',
#  'use',
#  'peace',
#  'let',
#  'us',
#  'resolve',
#  'era',
#  'enter',
#  'postwar',
#  'periods',
#  'often',
#  'time',
#  'retreat',
#  'isolation',
#  'leads',
#  'stagnation',
#  'home',
#  'invites',
#  'new',
#  'danger',
#  'abroad',
#  'let',
#  'us',
#  'resolve',
#  'become',
#  'time',
#  'great',
#  'responsibilities',
#  'greatly',
#  'borne',
#  'renew',
#  'spirit',
#  'promise',
# ...

# %% [markdown]
# ### Which word occurs the most number of times in his inaugural address for each president? Mention the top three words. (after removing the stopwords) – 3 Marks

# %%
dp1=df1.replace('[^\w\s-]','')

# %% [markdown]
# ### Most frequently occured words

# %%
all_words_freq1
# Out:
# FreqDist({'--': 25, 'nation': 12, 'know': 10, 'spirit': 9, 'life': 9, 'democracy': 9, 'us': 8, 'people': 7, 'america': 7, 'years': 6, ...})

# %% [markdown]
# word_features3 = [item[0] for item in all_words_freq3.most_common(1:4)]
# #word_features3 = most_common[0:3]

# %%
stopwords.append('--')

# %%
all_words_freq2
# Out:
# FreqDist({'--': 25, 'let': 16, 'us': 12, 'world': 8, 'sides': 8, 'new': 7, 'pledge': 7, 'citizens': 5, 'power': 5, 'shall': 5, ...})

# %%
all_words_freq3
# Out:
# FreqDist({'us': 26, 'let': 22, 'america': 21, 'peace': 19, 'world': 18, '--': 17, 'new': 15, 'nation': 11, 'responsibility': 11, 'government': 10, ...})

# %%
new_str = re.sub('[^a-zA-Z0-9.]', ' ', '1941-Roosevelt.txt')
open('b.txt', 'w').write(new_str)
# Out:
# 18

# %% [markdown]
# ### Top three words

# %%
word_features1[1:4]
# Out:
# ['nation', 'know', 'spirit']

# %%
word_features2[1:4]
# Out:
# ['let', 'us', 'world']

# %%
word_features3[0:3]
# Out:
# ['us', 'let', 'america']

# %%
stopwords.append('--')

# %% [markdown]
# ### Plot the word cloud of each of the speeches of the variable. (after removing the stopwords)

# %%
from wordcloud import WordCloud
import matplotlib.pyplot as plt 
def plot_cloud(wordcloud):
    plt.figure(figsize=(10, 10))
    plt.imshow(wordcloud) 
    plt.axis("off");
wordcloud = WordCloud(width = 500, height = 500, background_color='pink', random_state=10).generate(df)
plot_cloud(wordcloud)

# %%
def plot_cloud(wordcloud):
    plt.figure(figsize=(10, 10))
    plt.imshow(wordcloud) 
    plt.axis("off");
wordcloud = WordCloud(width = 500, height = 500, background_color='pink', random_state=10).generate(df1)
plot_cloud(wordcloud)

# %%
def plot_cloud(wordcloud):
    plt.figure(figsize=(10, 10))
    plt.imshow(wordcloud) 
    plt.axis("off");
wordcloud = WordCloud(width = 500, height = 500, background_color='pink', random_state=10).generate(df2)
plot_cloud(wordcloud)
